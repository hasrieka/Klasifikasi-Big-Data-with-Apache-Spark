# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df1 = pd.read_csv("/content/drive/MyDrive/Stemming/Train1_stemmed_lemmatized.csv", usecols=[ "text_lemmatize","label"])
df2 = pd.read_csv("/content/drive/MyDrive/Stemming/Train2_stemmed_lemmatized.csv", usecols=[ "text_lemmatize","label"])
df3 = pd.read_csv("/content/drive/MyDrive/Stemming/Train3_stemmed_lemmatized.csv", usecols=[ "text_lemmatize","label"])
df4 = pd.read_csv("/content/drive/MyDrive/Stemming/Train4_stemmed_lemmatized.csv", usecols=[ "text_lemmatize","label"])
df5 = pd.read_csv("/content/drive/MyDrive/Stemming/Train5_stemmed_lemmatized.csv", usecols=[ "text_lemmatize","label"])
df6 = pd.read_csv("/content/drive/MyDrive/Stemming/Train6_stemmed_lemmatized.csv", usecols=[ "text_lemmatize","label"])
df7 = pd.read_csv("/content/drive/MyDrive/Stemming/Train7_stemmed_lemmatized.csv", usecols=[ "text_lemmatize","label"])
df8 = pd.read_csv("/content/drive/MyDrive/Stemming/Train8_stemmed_lemmatized.csv", usecols=[ "text_lemmatize","label"])
df9 = pd.read_csv("/content/drive/MyDrive/Stemming/Train9_stemmed_lemmatized.csv", usecols=[ "text_lemmatize","label"])

# %%
df1.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-16ec5d44525a> in <module>()
# ----> 1 df1.head(20)
#
# NameError: name 'df1' is not defined

# %%
data1 = pd.concat([df1, df2])
data2 = pd.concat([data1, df3])
data3 = pd.concat([data2, df4])
data4 = pd.concat([data3, df5])
data5 = pd.concat([data4, df6])
data6 = pd.concat([data5, df7])
data7 = pd.concat([data6, df8])
data8 = pd.concat([data7, df9])

# %%
data15gb = pd.concat([data8, data8])

# %%
data8.head(100)
# Out:
#     label                                     text_lemmatize
# 0       2  sound track beautiful paint senery mind well w...
# 1       2  im reading lot review saying best game soundtr...
# 2       2  soundtrack favorite music time hand intense sa...
# 3       2  truly like soundtrack enjoy video game music p...
# 4       2  youve played game know divine music every sing...
# ..    ...                                                ...
# 95      1  book wriiten horribly would never life recomme...
# 96      2  train shape peg winning combination guaranteed...
# 97      1  remember getting book faintly say alot opinion...
# 98      2  think deodato concert rich used real string ba...
# 99      1  track original version rerecorded version whet...
#
# [100 rows x 2 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 799995 entries, 0 to 399996
# Data columns (total 2 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   label           799995 non-null  int64
#  1   text_lemmatize  799995 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 18.3+ MB

# %%
data8.isnull().sum()
# Out:
# label             0
# text_lemmatize    0
# dtype: int64

# %%
filename = 'data15gb.csv'
data15gb.to_csv(filename,index=False)

print('Saved file: ' + filename)

#move file to drive
# !mv /content/data15gb.csv /content/drive/MyDrive/"Data Fix"/
print('Done')
# Out:
# Saved file: data15gb.csv
# Done
